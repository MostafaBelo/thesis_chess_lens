# %%
import numpy as np
from matplotlib import pyplot as plt

import torch

import cv2

import importlib
import sys
sys.path.append('BoardDetector_Yolo')
import ChessLens
importlib.reload(ChessLens);

# %%
# img = ChessLens.ChessLensImage('data/data_manual/1741715439429.jpg')
img = ChessLens.ChessLensImage('data/data_manual/1741715439470.jpg')
# Out:
# (torch.uint8, tensor(255, dtype=torch.uint8))

# %%
img.detect_board()
# img.recognize_clock()
img.recognize_pieces()
img.save_fen_image()
# Out:
# here torch.Size([3000, 4000, 3]) torch.uint8 tensor(255, dtype=torch.uint8)
# passed
#
# 0: 640x640 1 chessboard, 61.1ms
# Speed: 2.3ms preprocess, 61.1ms inference, 256.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 black-bishop, 1 black-king, 2 black-knights, 5 black-pawns, 1 black-queen, 3 black-rooks, 1 white-bishop, 2 white-kings, 2 white-knights, 5 white-pawns, 2 white-rooks, 99.4ms
# Speed: 4.8ms preprocess, 99.4ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)

# %%
plt.figure(figsize=(10, 10))

plt.subplot(1,2,1)
# plt.imshow(img.img.permute(1,0,2).flip(0));
plt.imshow(img.img);
plt.subplot(1,2,2)
plt.imshow(plt.imread("out_fen.png"));
img.fen
# Out:
# 'r1qr4/pr2n1k1/1p1Rp1Pp/n3Pp2/2N3PN/2K2B2/PR3P2/6K1'
