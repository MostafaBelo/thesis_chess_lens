# %%
import torch

from matplotlib import pyplot as plt

from Dataset.DataSetLoaders.ChessDataset import ChessDataset

# %%
torch.cuda.is_available()
# Out:
# /home/mostafaelfaggal/.local/lib/python3.13/site-packages/torch/cuda/__init__.py:174: UserWarning: CUDA initialization: Unexpected error from cudaGetDeviceCount(). Did you run some cuda functions before calling NumCudaDevices() that might have already set an error? Error 804: forward compatibility was attempted on non supported HW (Triggered internally at /pytorch/c10/cuda/CUDAFunctions.cpp:109.)
#   return torch._C._cuda_getDeviceCount() > 0
# False

# %%
dataset = ChessDataset(force_build_pkl=True)
dataloader = ChessDataset.getLoader(dataset, batch_size=64, num_worders=4)

# %%
for img, label in dataloader:
    img: torch.Tensor = img
    plt.imshow(img[0].permute(1,2,0));
    # print(label)
    break
# Out:
# /home/mostafaelfaggal/.local/lib/python3.13/site-packages/torch/utils/data/dataloader.py:665: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)

# %%
label.keys()
# Out:
# dict_keys(['id', 'image_path', 'fen', 'orientation', 'corners', 'board_tensor'])

# %%
key = "corners"
len(label[key]), label[key]
# Out:
# (64,
#  tensor([[[144.,  78.],
#           [473.,  85.],
#           [636., 393.],
#           [ 12., 413.]],
#
#          [[153., 104.],
#           [463., 109.],
#           [613., 398.],
#           [ 34., 418.]],
#
#          [[138.,  86.],
#           [466.,  89.],
#           [634., 393.],
#           [  6., 425.]],
#
#          [[137.,  71.],
#           [463.,  51.],
#           [612., 351.],
#           [ 29., 392.]],
#
#          [[136.,  86.],
#           [465.,  89.],
#           [635., 393.],
#           [  7., 427.]],
#
#          [[159., 120.],
#           [471., 121.],
#           [623., 429.],
#           [ 17., 436.]],
#
#          [[149.,  34.],
#           [488.,  53.],
#           [634., 371.],
#           [ 13., 369.]],
#
#          [[161., 120.],
#           [474., 121.],
#           [625., 431.],
#           [ 18., 436.]],
#
#          [[151., 103.],
#           [463., 108.],
#           [610., 396.],
#           [ 31., 417.]],
#
#          [[154.,  70.],
#           [476.,  58.],
#           [615., 360.],
#           [ 34., 378.]],
#
#          [[155., 121.],
#           [466., 118.],
#           [622., 418.],
#           [ 23., 436.]],
#
#          [[150.,  73.],
#           [474.,  58.],
#           [626., 362.],
#           [ 34., 392.]],
#
#          [[155., 121.],
#           [466., 118.],
#           [622., 418.],
#           [ 23., 436.]],
#
#          [[154.,  70.],
#           [476.,  58.],
#           [615., 360.],
#           [ 34., 378.]],
#
#          [[154.,  70.],
#           [476.,  58.],
#           [615., 360.],
#           [ 34., 378.]],
#
#          [[150.,  73.],
#           [474.,  59.],
#           [625., 363.],
#           [ 34., 391.]],
#
#          [[149., 109.],
#           [458., 126.],
#           [595., 419.],
#           [  8., 422.]],
#
#          [[161., 119.],
#           [467., 127.],
#           [611., 422.],
#           [ 31., 427.]],
#
#          [[163., 122.],
#           [467., 132.],
#           [611., 425.],
#           [ 30., 428.]],
#
#          [[156., 120.],
#           [471., 123.],
#           [619., 438.],
#           [  4., 442.]],
#
#          [[137.,  85.],
#           [466.,  89.],
#           [634., 394.],
#           [  7., 425.]],
#
#          [[150.,  73.],
#           [474.,  58.],
#           [626., 362.],
#           [ 34., 392.]],
#
#          [[159., 120.],
#           [471., 121.],
#           [623., 429.],
#           [ 17., 436.]],
#
#          [[137.,  86.],
#           [466.,  89.],
#           [634., 391.],
#           [  6., 426.]],
#
#          [[150., 127.],
#           [456., 122.],
#           [610., 413.],
#           [ 24., 445.]],
#
#          [[150.,  73.],
#           [474.,  59.],
#           [626., 362.],
#           [ 35., 391.]],
#
#          [[150.,  73.],
#           [474.,  58.],
#           [626., 363.],
#           [ 34., 393.]],
#
#          [[150.,  73.],
#           [474.,  58.],
#           [627., 363.],
#           [ 34., 393.]],
#
#          [[172., 126.],
#           [476., 130.],
#           [623., 426.],
#           [ 45., 430.]],
#
#          [[153., 121.],
#           [466., 122.],
#           [622., 433.],
#           [ 10., 447.]],
#
#          [[148.,  74.],
#           [474.,  65.],
#           [616., 378.],
#           [ 15., 396.]],
#
#          [[144.,  79.],
#           [473.,  85.],
#           [636., 393.],
#           [ 10., 414.]],
#
#          [[159., 120.],
#           [471., 121.],
#           [623., 429.],
#           [ 17., 436.]],
#
#          [[149.,  74.],
#           [474.,  61.],
#           [614., 377.],
#           [ 14., 393.]],
#
#          [[157., 120.],
#           [468., 119.],
#           [623., 420.],
#           [ 23., 436.]],
#
#          [[154.,  70.],
#           [476.,  58.],
#           [615., 360.],
#           [ 34., 378.]],
#
#          [[137.,  71.],
#           [464.,  53.],
#           [612., 349.],
#           [ 29., 392.]],
#
#          [[144.,  79.],
#           [473.,  85.],
#           [637., 393.],
#           [ 12., 413.]],
#
#          [[170., 133.],
#           [476., 132.],
#           [628., 427.],
#           [ 46., 439.]],
#
#          [[137.,  71.],
#           [463.,  51.],
#           [612., 351.],
#           [ 29., 392.]],
#
#          [[154.,  71.],
#           [476.,  58.],
#           [615., 360.],
#           [ 34., 377.]],
#
#          [[158., 120.],
#           [469., 119.],
#           [623., 420.],
#           [ 22., 435.]],
#
#          [[136.,  86.],
#           [464.,  88.],
#           [635., 392.],
#           [  6., 427.]],
#
#          [[163., 118.],
#           [470., 114.],
#           [632., 403.],
#           [ 50., 427.]],
#
#          [[165., 127.],
#           [473., 117.],
#           [633., 410.],
#           [ 51., 443.]],
#
#          [[155., 121.],
#           [466., 118.],
#           [622., 416.],
#           [ 23., 436.]],
#
#          [[150.,  73.],
#           [474.,  58.],
#           [625., 364.],
#           [ 34., 393.]],
#
#          [[142., 104.],
#           [453., 105.],
#           [605., 391.],
#           [ 27., 424.]],
#
#          [[153., 109.],
#           [462., 124.],
#           [600., 419.],
#           [ 16., 421.]],
#
#          [[138.,  71.],
#           [462.,  52.],
#           [612., 349.],
#           [ 30., 389.]],
#
#          [[155., 121.],
#           [466., 118.],
#           [622., 418.],
#           [ 23., 436.]],
#
#          [[142.,  80.],
#           [470.,  88.],
#           [633., 395.],
#           [  8., 415.]],
#
#          [[138.,  71.],
#           [462.,  52.],
#           [612., 349.],
#           [ 30., 389.]],
#
#          [[144.,  79.],
#           [473.,  85.],
#           [637., 393.],
#           [ 12., 413.]],
#
#          [[154., 128.],
#           [458., 132.],
#           [607., 422.],
#           [ 22., 436.]],
#
#          [[144.,  79.],
#           [473.,  85.],
#           [637., 393.],
#           [ 12., 413.]],
#
#          [[136.,  86.],
#           [465.,  89.],
#           [635., 393.],
#           [  7., 427.]],
#
#          [[158., 120.],
#           [468., 119.],
#           [623., 420.],
#           [ 23., 436.]],
#
#          [[143., 135.],
#           [449., 111.],
#           [621., 392.],
#           [ 52., 455.]],
#
#          [[142.,  80.],
#           [470.,  88.],
#           [634., 394.],
#           [  8., 415.]],
#
#          [[161., 120.],
#           [474., 121.],
#           [625., 431.],
#           [ 18., 436.]],
#
#          [[136.,  86.],
#           [465.,  89.],
#           [635., 393.],
#           [  7., 427.]],
#
#          [[154.,  70.],
#           [476.,  58.],
#           [615., 360.],
#           [ 34., 378.]],
#
#          [[139.,  51.],
#           [477.,  63.],
#           [633., 377.],
#           [  8., 390.]]]))
